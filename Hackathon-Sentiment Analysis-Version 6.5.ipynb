# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt 
import matplotlib.cm as cm #color plot
import matplotlib
import seaborn as sns
import csv
from math import *

from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer 
from sklearn.decomposition import LatentDirichletAllocation,TruncatedSVD
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE

from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import VotingClassifier
from sklearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold

from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import RegexpTokenizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

import re
import unicodedata
# Out:
# C:\Users\there\Anaconda3\lib\site-packages\ipykernel\parentpoller.py:116: UserWarning: Parent poll failed.  If the frontend dies,
#                 the kernel may be left running.  Please let us know
#                 about your system (bitness, Python, etc.) at
#                 ipython-dev@scipy.org
#   ipython-dev@scipy.org""")
# C:\Users\there\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# C:\Users\there\Anaconda3\lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn("The twython library has not been installed. "

# %% [markdown]
# ### Reading in the training csv data as a df

# %%
reviews_train = pd.read_csv('train.csv')
reviews_train = reviews_train.drop(columns=['asin', 'helpful', 'reviewTime', 'reviewerID', 'reviewerName', 'unixReviewTime'])
reviews_train
# Out:
#        overall                                         reviewText  \
# 0            1  I bought this because my audio cord for the ca...
# 1            1  Arrived ok, but within a week started to reboo...
# 2            5  Came on time and had a super long cord and had...
# 3            3  The Waterboys of the 80's are tough to discern...
# 4            5  My laptop only have a micro hdmi output and th...
# 5            5  Excellent fit, finish, and quality at a reason...
# 6            5  This has a fold-out plug for charging at a wal...
# 7            5  I've been using this case for 6 months now and...
# 8            4  I have an older xbox with the 20 gb hard drive...
# 9            4  This case fits my daughter's S-2110 tablet per...
# 10           4  the story is fast paced without being obnoxiou...
# 11           4  The movie arrived as promised and in excellent...
# 12           5  A must have if you are cloning laptop hard dri...
# 13           5  For the price vs performance, I really don't k...
# 14           5  worked great would order more next time came r...
# 15           2  It does what its supposed to do, but it only w...
# 16           4  Summary - Like a funny version of any Star Tre...
# 17           5  You can tell from a lot of review titles that ...
# 18           1                                                NaN
# 19           5  I thought that this movie was pretty good. it ...
# 20           5  I live about 35 miles due west of Chicago and ...
# 21           5  Does a great job covering the Kindle and daugh...
# 22           2  I fell for the hype.When Deutsche Grammophon a...
# 23           2  I bought this set of DVDs when I heard that th...
# 24           5  Most charging cords I have had last a few week...
# 25           5                                                NaN
# 26           5  This is basically the middle in the riddick sa...
# 27           4  arrived on time . This was a very good dvd for...
# 28           5  I always love Diana's music. She has something...
# 29           5  It's a nice fast card, Don't know if its the c...
# ...        ...                                                ...
# 34885        4  So we have a bluray player and a directv DVR. ...
# 34886        2  Beware of the "Smart TV"Today's  DHS daily ema...
# 34887        5  Very good addition to my HP dc5800 Small Form ...
# 34888        2  Pretty pictures of the GobiI dessert but not e...
# 34889        1                                                NaN
# 34890        4  I am also from the Detroit MI area and when I ...
# 34891        1                                                NaN
# 34892        5  Barbara Hershey is never less than watchable i...
# 34893        3  First issue:  The unit has three different inp...
# 34894        5  I got this a little hesitant because I'd bough...
# 34895        4  This is a great product as most Logitech's are...
# 34896        1  I know I'm going to be told I'm wrong, but thi...
# 34897        3  this is what life is like. Mild spoilers. And ...
# 34898        4  The 414 was easy to set up and is very quiet. ...
# 34899        3  This was part of one of those 8 films for $5 D...
# 34900        5  I stumbled across this movie on the TV one aft...
# 34901        5  Love this collection of eclectic music from th...
# 34902        5  I have a mid 2010 macbook pro and this charger...
# 34903        4  My daughter loves all movies about whales and ...
# 34904        5  Starting with the keyboard (Logitech K350), I ...
# 34905        5  I bought this because my Acer Netbook does not...
# 34906        5  As other Lowepro products, this bag looks good...
# 34907        4  Wonderful dichotomy of how the Christmas story...
# 34908        4  Content: Certain episodes are triumphs of pres...
# 34909        5  I've only tested it but it and works perfectly...
# 34910        3  I love female vocalists with good voices.  Lar...
# 34911        5  I seen this movie years ago I purchased it bec...
# 34912        2  Love Mel Brooks. This one just plain sucked !T...
# 34913        4  A poor scrapper from Boston writes a script th...
# 34914        5  Very good movie. Actors do a great job. Good s...
#
#                                                  summary categoryName
# 0                                            didn't help    CellPhone
# 1                               Coby Kyros 8 inch tablet  Electronics
# 2                Awesome Awesome Awesome surge protector  Electronics
# 3                             Mike Scott in a weary land      CDVinyl
# 4                         Good quality, work as expected  Electronics
# 5                              Excellent fit and finish.  Electronics
# 6         Works great, batteries are not as pictured tho  Electronics
# 7                                      Perfect for my N7  Electronics
# 8                             Purchased for xbox storage  Electronics
# 9                                          it fits!!!!!!  Electronics
# 10                             one of the better ones...      MovieTV
# 11                              Romeo Must Die....again?      MovieTV
# 12                               Excellent piece of gear  Electronics
# 13                Works and is simple and price is right  Electronics
# 14     would have ordered more could have instruction...    CellPhone
# 15                                             Just "EH"    CellPhone
# 16           Funny satire on a bunch of space franchises      MovieTV
# 17                                        Yes, it works!  Electronics
# 18     I only ordered to use the back protector, have...  Electronics
# 19                                         Pain And Gain      MovieTV
# 20                              Great given the distance  Electronics
# 21                 Get compliments on cover all the time  Electronics
# 22                                Woefully misconceived!      CDVinyl
# 23                   Mistake to return to your childhood      MovieTV
# 24                               This one actually lasts  Electronics
# 25                             good bye cable hello roku  Electronics
# 26                                            middle man      MovieTV
# 27                          Sesame Street Favorite Songs      MovieTV
# 28                                     The Boss of stage      CDVinyl
# 29                                 It's a nice fast card  Electronics
# ...                                                  ...          ...
# 34885               I'm at my WITS' end with this thing!  Electronics
# 34886     Beware of the "Smart TV" - DHS security update  Electronics
# 34887                               Excellent DVD-Writer  Electronics
# 34888                                 Another 3d mistake      MovieTV
# 34889  Fantastic audiophile headphones, totally worth...  Electronics
# 34890                                          Sugar Man      CDVinyl
# 34891                               Broke after two uses  Electronics
# 34892  One of the most intense films of the 1980s and...      MovieTV
# 34893  Decent sound, but not a thoroughly engineered ...  Electronics
# 34894                               Best Privacy Screen!    CellPhone
# 34895            A great smaller sized wireless keyboard  Electronics
# 34896                      Not your usual Celtic Thunder      MovieTV
# 34897                             Hurts to watch, but...      MovieTV
# 34898  No transcoding capabilities in an otherwise go...  Electronics
# 34899  Classic concept, OK execution...but who was th...      MovieTV
# 34900                                      a lovely film      MovieTV
# 34901                             Just as Great as Mix 1      CDVinyl
# 34902                Great car charger for a Macbook Pro  Electronics
# 34903                               my daughter liked it      MovieTV
# 34904     Great keyboard and mouse, but has some caveats  Electronics
# 34905            Great for Netbooks and certain laptops.  Electronics
# 34906             Really good, as other Lowepro products  Electronics
# 34907                               Great Christmas Tale      MovieTV
# 34908  Entertaining, not terribly deep, good a/v qual...      MovieTV
# 34909               cool lil camera, works great so far.  Electronics
# 34910                  Pretty Voice, but very boring CD!      CDVinyl
# 34911                        product of license to drive      MovieTV
# 34912      Love Mel Brooks. This one just plain sucked !      MovieTV
# 34913                           Going For The Whole Hog!      MovieTV
# 34914                                              OPA!!      MovieTV
#
# [34915 rows x 4 columns]

# %% [markdown]
# ### Reading in the testing csv data as a df

# %%
reviews_test = pd.read_csv('test.csv')

reviews_test = reviews_test[['reviewText', 'summary', 'categoryName']]

reviews_test
# Out:
#                                              reviewText  \
# 0     This is black metal by definition with the evi...
# 1     Another classic, great for the family movie by...
# 2     I'm a big proponent for LG televisions because...
# 3     Rock 'n Roll lost a true guitar legend when Al...
# 4     I know I might stir the pot with this review. ...
# 5     This product was shipped normal and arrived sl...
# 6     It works for ipad 3 too. Great protector, no c...
# 7     Bought these to save some money on batteries. ...
# 8     it fits well and is great for taking a netbook...
# 9     I have seen Holmes in many guises, most of whi...
# 10    I love everything about this camera except one...
# 11    It's cute, it has a nice color and attractive ...
# 12    I could list a whole string of adjectives, but...
# 13    Yuck frontman Daniel Blumberg made a curious d...
# 14    A handy item. When I put a long HDMI cable ins...
# 15    I first saw Ryan Adams in the 1990s with Whisk...
# 16    I really like that it charges 2 devices at one...
# 17    Cute and fun colors. Works as expected and the...
# 18    After giving up on the last few, I bought the ...
# 19    I had seen "Carousel" before on a used cassett...
# 20    This package contains 4 rolls of Velcro ties. ...
# 21    Bought this dongle for 9 bucks, mimo provides ...
# 22    I like the extreme series of boards from Intel...
# 23    Lorretta Devine is one of my favorite actresse...
# 24    This product is probably the best and most bel...
# 25    Great acting by Meryl Streep! She made me afra...
# 26    Ryan Gosling plays a terminally laid-back stun...
# 27    This introduced complex characters with a well...
# 28    This is a really great product that does exact...
# 29    I was pretty impressed with the durability of ...
# ...                                                 ...
# 1809  The controller arrived ahead of the console so...
# 1810  I thought this movie was ridiculous. I remembe...
# 1811  Well judging from the election results more pe...
# 1812  Only took 30 seconds to snugly fit my Paperwhi...
# 1813  Good plot and decent acting.  However, there i...
# 1814  Check out more anime reviews: The Huge Anime F...
# 1815  At first I thought the mirror look was elegant...
# 1816  If you have kids and especially if you're givi...
# 1817  I have an older Kindle that came with an adapt...
# 1818  I bought this game from Amazon because it was ...
# 1819  Great styluses but they do not have the little...
# 1820  pros:sounds amazing.wireless.base is awesome a...
# 1821  This is a great trilogy of hard to find movies...
# 1822  In my opinion this is the best Winnie the Pooh...
# 1823  Allen Stone is the real deal. A true musician ...
# 1824  With the arrival of Foggy and his Office signs...
# 1825  No, it doesn't have that original, fresh charm...
# 1826  I admired Princess Diana for the attention she...
# 1827  Read and write speed are super quick with my c...
# 1828  A 6 months warranty doesn't instill confidence...
# 1829  We've recently switched from independent small...
# 1830  This Viewsonic is 21.5 inches .  VERY light we...
# 1831  This case became an upgrade of my 9-year old A...
# 1832  This is an old family favorite.  It is great t...
# 1833  An all time favorite, I always remember when I...
# 1834  These speakers do an excellent job if you don'...
# 1835  It could be a 5 star product, but some lazy de...
# 1836  While I have had some hiccups with this keyboa...
# 1837  They are great for the whole family to reclaim...
# 1838  This is a terrific, excellent CD of Queen's Gr...
#
#                                                 summary categoryName
# 0                                      pure black metal      CDVinyl
# 1                                   My Neighbor Tortoro      MovieTV
# 2                        LG Television for the bedroom.  Electronics
# 3                   Alvin Lee......a true guitar legend      CDVinyl
# 4                         One Eyed Jacks Blu-Ray Review      MovieTV
# 5                                     Seller stepped up  Electronics
# 6                                  works for ipad 3 too  Electronics
# 7                                       Can't Charge Me  Electronics
# 8                                       is OK for price  Electronics
# 9                        Holmes as Doyle would know him      MovieTV
# 10                  Great but one really annoying issue  Electronics
# 11              Turned itself off the first day of use.  Electronics
# 12                          Absolutely the worst movie!      MovieTV
# 13    Indie rockers Yuck boldly emerge with new idea...      CDVinyl
# 14           an investment to preserve long HDMI cables  Electronics
# 15                        Lovely, an immediate favorite      CDVinyl
# 16    Great product- charges iPad and smartphone lik...  Electronics
# 17                                  Cute, Fun & Durable  Electronics
# 18       DVDs come scratched from factory - check yours      MovieTV
# 19                     A sad movie with beautiful music      MovieTV
# 20          Very nice! I found many uses for these ties  Electronics
# 21              Bumped my WiFi speed by a factor of 3-4  Electronics
# 22                                    top quality board  Electronics
# 23                                        Devine Comedy      MovieTV
# 24                                   Absolutely Love it      MovieTV
# 25                       Meryl Streep steals the screen      MovieTV
# 26                                      Comatose driver      MovieTV
# 27                               Riveting & Fascinating      MovieTV
# 28                                                 HDMI    CellPhone
# 29                                         Proffesional  Electronics
# ...                                                 ...          ...
# 1809                         controller arrived quickly   VideoGames
# 1810                                    Are you serious      MovieTV
# 1811                                &#34;Right &#34; On      MovieTV
# 1812     Looks super cool, smells great and fits snugly  Electronics
# 1813  Good plot, decent acting. Too much sex and vio...      MovieTV
# 1814                            Gets better than Part 1      MovieTV
# 1815  Compromises the display, more for looks rather...    CellPhone
# 1816                        a MUST HAVE for your Kindle  Electronics
# 1817  Works great but you may not need it, especiall...  Electronics
# 1818                               NOT THE FULL VERSION   VideoGames
# 1819                                     Great styluses    CellPhone
# 1820                great headphones but defectly built   VideoGames
# 1821                          Trilogy is a great value.      MovieTV
# 1822                        Buy it Now...terrific movie      MovieTV
# 1823           Wow for this young blue eyed soul genius      CDVinyl
# 1824                                    Foggy`s arrival      MovieTV
# 1825                             Unoriginal, Casual Fun   VideoGames
# 1826                            DON'T GET YOUR HOPES UP      MovieTV
# 1827                                     Solid mem card  Electronics
# 1828                                    Measly warranty  Electronics
# 1829               Great Shared Family Storage Solution  Electronics
# 1830                 Cheap Wide Screen For Your Desktop  Electronics
# 1831            XL-Full Tower case with lots of options  Electronics
# 1832                                Old family favorite      MovieTV
# 1833      Rockford Files, Unique  and Entertaining Show      MovieTV
# 1834                 Excellent, but expensive, speakers  Electronics
# 1835                             Sorry, not good enough  Electronics
# 1836                   Great keyboard; bad manufacturer   VideoGames
# 1837                            Disney movies are great      MovieTV
# 1838  This is a terrific, excellent CD of QUEEN'S gr...      CDVinyl
#
# [1839 rows x 3 columns]

# %% [markdown]
# ### Assign each review into three categories then only pick out the reviews with 45 words or more

# %%
cat = ['low','neutral','high']
def cat_y(y):
    if y<=2.0:
        return cat[0]
    elif y>=4.0:
        return cat[2]
    else:
        return cat[1]

reviews_train = reviews_train[reviews_train['reviewText'].notnull()] # Makes sure the reviews are not NaN (empty cells)
reviews_train = reviews_train[reviews_train['reviewText'].apply(lambda x: len(x.split())>=45)] #splits the data into those with more than 45 word reviews
reviews_train['bucket'] = reviews_train['overall'].apply(cat_y) # apply the category sorting


#dropped rows having NaN values
reviews_train = reviews_train.dropna()

#re-index the dataframe
reviews_train = reviews_train.reset_index()
del reviews_train['index']

reviews_train

#shows the dataframe with the new category rankings and reviews that are more than 45 characters long
# Out:
#        overall                                         reviewText  \
# 0            5  Came on time and had a super long cord and had...
# 1            3  The Waterboys of the 80's are tough to discern...
# 2            5  I've been using this case for 6 months now and...
# 3            4  I have an older xbox with the 20 gb hard drive...
# 4            4  the story is fast paced without being obnoxiou...
# 5            4  The movie arrived as promised and in excellent...
# 6            5  A must have if you are cloning laptop hard dri...
# 7            5  For the price vs performance, I really don't k...
# 8            4  Summary - Like a funny version of any Star Tre...
# 9            5  You can tell from a lot of review titles that ...
# 10           5  I thought that this movie was pretty good. it ...
# 11           5  I live about 35 miles due west of Chicago and ...
# 12           2  I fell for the hype.When Deutsche Grammophon a...
# 13           2  I bought this set of DVDs when I heard that th...
# 14           5  This is basically the middle in the riddick sa...
# 15           4  arrived on time . This was a very good dvd for...
# 16           5  I always love Diana's music. She has something...
# 17           5  It's a nice fast card, Don't know if its the c...
# 18           5  Seems to be a lot of nitpicking in these revie...
# 19           5  I purchased this after reading all the reviews...
# 20           2  First one would go to sleep and not wake up wi...
# 21           5  Clint did his usual best as the old gunslinger...
# 22           5  For the Pictures to really "work", its conduct...
# 23           1  I am not surprise to see so many 5 star review...
# 24           5  As stated in the title, I bought this drive fo...
# 25           3  I think this is one of Malle's best movie I've...
# 26           5  I bought my Kindle 3 years ago -- before the n...
# 27           5  Great device I ordered for my dad and he loves...
# 28           5  Since this is a universal case, I had lower ex...
# 29           4  In short, this seems to have been designed and...
# ...        ...                                                ...
# 20553        4  It takes a bit of time to heat up, but "Ides o...
# 20554        5  This is considered Miles Davis' first fusion a...
# 20555        5  Red Fang have been tearing it up on tour suppo...
# 20556        4  As Bluetooth mice go, this is a solid performe...
# 20557        3  I love WCAR. Love, love, love them! UWWGTB is ...
# 20558        5  Very good quality headphone system that simply...
# 20559        5  Some great songs on this album including Ponch...
# 20560        5  This is a great lens.  Close focus is unbeliev...
# 20561        5  This case fits my nexus 7 perfect. All the cut...
# 20562        5  This is a less expensive option to the BlackRa...
# 20563        4  So we have a bluray player and a directv DVR. ...
# 20564        2  Beware of the "Smart TV"Today's  DHS daily ema...
# 20565        2  Pretty pictures of the GobiI dessert but not e...
# 20566        5  Barbara Hershey is never less than watchable i...
# 20567        3  First issue:  The unit has three different inp...
# 20568        5  I got this a little hesitant because I'd bough...
# 20569        1  I know I'm going to be told I'm wrong, but thi...
# 20570        3  this is what life is like. Mild spoilers. And ...
# 20571        4  The 414 was easy to set up and is very quiet. ...
# 20572        3  This was part of one of those 8 films for $5 D...
# 20573        5  I stumbled across this movie on the TV one aft...
# 20574        5  I have a mid 2010 macbook pro and this charger...
# 20575        4  My daughter loves all movies about whales and ...
# 20576        5  Starting with the keyboard (Logitech K350), I ...
# 20577        5  I bought this because my Acer Netbook does not...
# 20578        4  Wonderful dichotomy of how the Christmas story...
# 20579        4  Content: Certain episodes are triumphs of pres...
# 20580        5  I seen this movie years ago I purchased it bec...
# 20581        2  Love Mel Brooks. This one just plain sucked !T...
# 20582        4  A poor scrapper from Boston writes a script th...
#
#                                                  summary categoryName   bucket
# 0                Awesome Awesome Awesome surge protector  Electronics     high
# 1                             Mike Scott in a weary land      CDVinyl  neutral
# 2                                      Perfect for my N7  Electronics     high
# 3                             Purchased for xbox storage  Electronics     high
# 4                              one of the better ones...      MovieTV     high
# 5                               Romeo Must Die....again?      MovieTV     high
# 6                                Excellent piece of gear  Electronics     high
# 7                 Works and is simple and price is right  Electronics     high
# 8            Funny satire on a bunch of space franchises      MovieTV     high
# 9                                         Yes, it works!  Electronics     high
# 10                                         Pain And Gain      MovieTV     high
# 11                              Great given the distance  Electronics     high
# 12                                Woefully misconceived!      CDVinyl      low
# 13                   Mistake to return to your childhood      MovieTV      low
# 14                                            middle man      MovieTV     high
# 15                          Sesame Street Favorite Songs      MovieTV     high
# 16                                     The Boss of stage      CDVinyl     high
# 17                                 It's a nice fast card  Electronics     high
# 18                                    Superb for running  Electronics     high
# 19     Watch for grey market items | James Edward Pho...  Electronics     high
# 20     Great, but intereferes with my OTA (Over The A...  Electronics      low
# 21                                 A Classic Western!!!!      MovieTV     high
# 22     Bernstein turns the Pictures into an event, ex...      CDVinyl     high
# 23     Some people will believe anything you tell them!!      MovieTV      low
# 24                 256 GB SSD for Macbook Pro (Mid-2010)  Electronics     high
# 25                                           Pretty Baby      MovieTV  neutral
# 26                              Perfect Light for Kindle  Electronics     high
# 27            Great External Battery @ a great price!!!!  Electronics     high
# 28                           Perfect fit on a Zeepad 7.0  Electronics     high
# 29                Decent headset, but awkward to control  Electronics     high
# ...                                                  ...          ...      ...
# 20553                                 Politics as usual?      MovieTV     high
# 20554           1969 jazz fusion classic: two long songs      CDVinyl     high
# 20555         A great rock/punk/metal brew from Red Fang      CDVinyl     high
# 20556                      Good mouse for a decent price  Electronics     high
# 20557                   Tracing Back Roots makes me sad.      CDVinyl  neutral
# 20558                             Landline Phone Freedom  Electronics     high
# 20559                           Good Songs and Bad Jokes      CDVinyl     high
# 20560                     Great lens on my Oly OM-D EM-5  Electronics     high
# 20561                      Great Case and a Bargan price  Electronics     high
# 20562           Less Expensive Option to BR Double Strap  Electronics     high
# 20563               I'm at my WITS' end with this thing!  Electronics     high
# 20564     Beware of the "Smart TV" - DHS security update  Electronics      low
# 20565                                 Another 3d mistake      MovieTV      low
# 20566  One of the most intense films of the 1980s and...      MovieTV     high
# 20567  Decent sound, but not a thoroughly engineered ...  Electronics  neutral
# 20568                               Best Privacy Screen!    CellPhone     high
# 20569                      Not your usual Celtic Thunder      MovieTV      low
# 20570                             Hurts to watch, but...      MovieTV  neutral
# 20571  No transcoding capabilities in an otherwise go...  Electronics     high
# 20572  Classic concept, OK execution...but who was th...      MovieTV  neutral
# 20573                                      a lovely film      MovieTV     high
# 20574                Great car charger for a Macbook Pro  Electronics     high
# 20575                               my daughter liked it      MovieTV     high
# 20576     Great keyboard and mouse, but has some caveats  Electronics     high
# 20577            Great for Netbooks and certain laptops.  Electronics     high
# 20578                               Great Christmas Tale      MovieTV     high
# 20579  Entertaining, not terribly deep, good a/v qual...      MovieTV     high
# 20580                        product of license to drive      MovieTV     high
# 20581      Love Mel Brooks. This one just plain sucked !      MovieTV      low
# 20582                           Going For The Whole Hog!      MovieTV     high
#
# [20583 rows x 5 columns]

# %%
reviews_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20583 entries, 0 to 20582
# Data columns (total 5 columns):
# overall         20583 non-null int64
# reviewText      20583 non-null object
# summary         20583 non-null object
# categoryName    20583 non-null object
# bucket          20583 non-null object
# dtypes: int64(1), object(4)
# memory usage: 804.1+ KB

# %%
reviews_train.describe()
# Out:
#             overall
# count  20583.000000
# mean       4.066511
# std        1.232317
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
info = pd.pivot_table(reviews_train,index=['categoryName'],values=['overall', 'reviewText'],
               columns=[],aggfunc=[np.sum, np.mean],fill_value=0)

print(info.head())


info_test = pd.pivot_table(reviews_test,index=['categoryName'],
               columns=[],aggfunc=[np.sum],fill_value=0)

print(info_test.head())
# Out:
#                  sum      mean
#              overall   overall
# categoryName
# CDVinyl        11660  4.388408
# CellPhone       5791  3.955601
# Electronics    39447  4.033023
# MovieTV        26803  4.011825
#                                                             sum  \
#                                                      reviewText
# categoryName
# CDVinyl       This is black metal by definition with the evi...
# CellPhone     This is a really great product that does exact...
# Electronics   I'm a big proponent for LG televisions because...
# MovieTV       Another classic, great for the family movie by...
# VideoGames    These headphones are great but nothing is perf...
#
#
#                                                         summary
# categoryName
# CDVinyl       pure black metalAlvin Lee......a true guitar l...
# CellPhone     HDMIA surprisingly well-built holder with a fe...
# Electronics   LG Television for the bedroom.Seller stepped u...
# MovieTV       My Neighbor TortoroOne Eyed Jacks Blu-Ray Revi...
# VideoGames    Can you hear me now?Great.  I loved it.Exelent...

# %% [markdown]
# ### Getting rid of contractions

# %%
#Getting rid of contractions
cList = {
  "ain't": "am not",
  "aren't": "are not",
  "can't": "cannot",
  "can't've": "cannot have",
  "'cause": "because",
  "could've": "could have",
  "couldn't": "could not",
  "couldn't've": "could not have",
  "didn't": "did not",
  "doesn't": "does not",
  "don't": "do not",
  "hadn't": "had not",
  "hadn't've": "had not have",
  "hasn't": "has not",
  "haven't": "have not",
  "he'd": "he would",
  "he'd've": "he would have",
  "he'll": "he will",
  "he'll've": "he will have",
  "he's": "he is",
  "how'd": "how did",
  "how'd'y": "how do you",
  "how'll": "how will",
  "how's": "how is",
  "I'd": "I would",
  "i've": "I have",
  "I'd've": "I would have",
  "I'll": "I will",
  "I'll've": "I will have",
  "I'm": "I am",
  "I've": "I have",
  "isn't": "is not",
  "it'd": "it had",
  "it'd've": "it would have",
  "it'll": "it will",
  "it'll've": "it will have",
  "it's": "it is",
  "let's": "let us",
  "ma'am": "madam",
  "mayn't": "may not",
  "might've": "might have",
  "mightn't": "might not",
  "mightn't've": "might not have",
  "must've": "must have",
  "mustn't": "must not",
  "mustn't've": "must not have",
  "needn't": "need not",
  "needn't've": "need not have",
  "o'clock": "of the clock",
  "oughtn't": "ought not",
  "oughtn't've": "ought not have",
  "shan't": "shall not",
  "sha'n't": "shall not",
  "shan't've": "shall not have",
  "she'd": "she would",
  "she'd've": "she would have",
  "she'll": "she will",
  "she'll've": "she will have",
  "she's": "she is",
  "should've": "should have",
  "shouldn't": "should not",
  "shouldn't've": "should not have",
  "so've": "so have",
  "so's": "so is",
  "that'd": "that would",
  "that'd've": "that would have",
  "that's": "that is",
  "there'd": "there had",
  "there'd've": "there would have",
  "there's": "there is",
  "they'd": "they would",
  "they'd've": "they would have",
  "they'll": "they will",
  "they'll've": "they will have",
  "they're": "they are",
  "they've": "they have",
  "to've": "to have",
  "wasn't": "was not",
  "we'd": "we had",
  "we'd've": "we would have",
  "we'll": "we will",
  "we'll've": "we will have",
  "we're": "we are",
  "we've": "we have",
  "weren't": "were not",
  "what'll": "what will",
  "what'll've": "what will have",
  "what're": "what are",
  "what's": "what is",
  "what've": "what have",
  "when's": "when is",
  "when've": "when have",
  "where'd": "where did",
  "where's": "where is",
  "where've": "where have",
  "who'll": "who will",
  "who'll've": "who will have",
  "who's": "who is",
  "who've": "who have",
  "why's": "why is",
  "why've": "why have",
  "will've": "will have",
  "won't": "will not",
  "won't've": "will not have",
  "would've": "would have",
  "wouldn't": "would not",
  "wouldn't've": "would not have",
  "y'all": "you all",
  "y'alls": "you alls",
  "y'all'd": "you all would",
  "y'all'd've": "you all would have",
  "y'all're": "you all are",
  "y'all've": "you all have",
  "you'd": "you had",
  "you'd've": "you would have",
  "you'll": "you you will",
  "you'll've": "you you will have",
  "you're": "you are",
  "you've": "you have"
}

c_re = re.compile('(%s)' % '|'.join(cList.keys()))

def expandContractions(text, c_re=c_re):
    text = text.lower()
    def replace(match):
        return cList[match.group(0)]
    return c_re.sub(replace, text.lower())


all_reviews = reviews_train['reviewText']

all_clean_train_reviews = []

for i in range(0,20583):
    all_clean_train_reviews.append(expandContractions(all_reviews[i]))
    
reviews_train['reviewText_clean'] = all_clean_train_reviews

reviews_train['reviewText_clean']
# Out:
# 0        came on time and had a super long cord and had...
# 1        the waterboys of the 80's are tough to discern...
# 2        I have been using this case for 6 months now a...
# 3        i have an older xbox with the 20 gb hard drive...
# 4        the story is fast paced without being obnoxiou...
# 5        the movie arrived as promised and in excellent...
# 6        a must have if you are cloning laptop hard dri...
# 7        for the price vs performance, i really do not ...
# 8        summary - like a funny version of any star tre...
# 9        you can tell from a lot of review titles that ...
# 10       i thought that this movie was pretty good. it ...
# 11       i live about 35 miles due west of chicago and ...
# 12       i fell for the hype.when deutsche grammophon a...
# 13       i bought this set of dvds when i heard that th...
# 14       this is basically the middle in the riddick sa...
# 15       arrived on time . this was a very good dvd for...
# 16       i always love diana's music. she has something...
# 17       it is a nice fast card, do not know if its the...
# 18       seems to be a lot of nitpicking in these revie...
# 19       i purchased this after reading all the reviews...
# 20       first one would go to sleep and not wake up wi...
# 21       clint did his usual best as the old gunslinger...
# 22       for the pictures to really "work", its conduct...
# 23       i am not surprise to see so many 5 star review...
# 24       as stated in the title, i bought this drive fo...
# 25       i think this is one of malle's best movie I ha...
# 26       i bought my kindle 3 years ago -- before the n...
# 27       great device i ordered for my dad and he loves...
# 28       since this is a universal case, i had lower ex...
# 29       in short, this seems to have been designed and...
#                                ...
# 20553    it takes a bit of time to heat up, but "ides o...
# 20554    this is considered miles davis' first fusion a...
# 20555    red fang have been tearing it up on tour suppo...
# 20556    as bluetooth mice go, this is a solid performe...
# 20557    i love wcar. love, love, love them! uwwgtb is ...
# 20558    very good quality headphone system that simply...
# 20559    some great songs on this album including ponch...
# 20560    this is a great lens.  close focus is unbeliev...
# 20561    this case fits my nexus 7 perfect. all the cut...
# 20562    this is a less expensive option to the blackra...
# 20563    so we have a bluray player and a directv dvr. ...
# 20564    beware of the "smart tv"today's  dhs daily ema...
# 20565    pretty pictures of the gobii dessert but not e...
# 20566    barbara hershey is never less than watchable i...
# 20567    first issue:  the unit has three different inp...
# 20568    i got this a little hesitant because i'd bough...
# 20569    i know i'm going to be told i'm wrong, but thi...
# 20570    this is what life is like. mild spoilers. and ...
# 20571    the 414 was easy to set up and is very quiet. ...
# 20572    this was part of one of those 8 films for $5 d...
# 20573    i stumbled across this movie on the tv one aft...
# 20574    i have a mid 2010 macbook pro and this charger...
# 20575    my daughter loves all movies about whales and ...
# 20576    starting with the keyboard (logitech k350), i ...
# 20577    i bought this because my acer netbook does not...
# 20578    wonderful dichotomy of how the christmas story...
# 20579    content: certain episodes are triumphs of pres...
# 20580    i seen this movie years ago i purchased it bec...
# 20581    love mel brooks. this one just plain sucked !t...
# 20582    a poor scrapper from boston writes a script th...
# Name: reviewText_clean, Length: 20583, dtype: object

# %%
all_reviews_test = reviews_test['reviewText']

all_clean_test_reviews = []

for i in range(0,1839):
    all_clean_test_reviews.append(expandContractions(all_reviews_test[i]))
    
reviews_test['reviewText_clean'] = all_clean_test_reviews

reviews_test['reviewText_clean']
# Out:
# 0       this is black metal by definition with the evi...
# 1       another classic, great for the family movie by...
# 2       i'm a big proponent for lg televisions because...
# 3       rock 'n roll lost a true guitar legend when al...
# 4       i know i might stir the pot with this review. ...
# 5       this product was shipped normal and arrived sl...
# 6       it works for ipad 3 too. great protector, no c...
# 7       bought these to save some money on batteries. ...
# 8       it fits well and is great for taking a netbook...
# 9       i have seen holmes in many guises, most of whi...
# 10      i love everything about this camera except one...
# 11      it is cute, it has a nice color and attractive...
# 12      i could list a whole string of adjectives, but...
# 13      yuck frontman daniel blumberg made a curious d...
# 14      a handy item. when i put a long hdmi cable ins...
# 15      i first saw ryan adams in the 1990s with whisk...
# 16      i really like that it charges 2 devices at one...
# 17      cute and fun colors. works as expected and the...
# 18      after giving up on the last few, i bought the ...
# 19      i had seen "carousel" before on a used cassett...
# 20      this package contains 4 rolls of velcro ties. ...
# 21      bought this dongle for 9 bucks, mimo provides ...
# 22      i like the extreme series of boards from intel...
# 23      lorretta devine is one of my favorite actresse...
# 24      this product is probably the best and most bel...
# 25      great acting by meryl streep! she made me afra...
# 26      ryan gosling plays a terminally laid-back stun...
# 27      this introduced complex characters with a well...
# 28      this is a really great product that does exact...
# 29      i was pretty impressed with the durability of ...
#                               ...
# 1809    the controller arrived ahead of the console so...
# 1810    i thought this movie was ridiculous. i remembe...
# 1811    well judging from the election results more pe...
# 1812    only took 30 seconds to snugly fit my paperwhi...
# 1813    good plot and decent acting.  however, there i...
# 1814    check out more anime reviews: the huge anime f...
# 1815    at first i thought the mirror look was elegant...
# 1816    if you have kids and especially if you are giv...
# 1817    i have an older kindle that came with an adapt...
# 1818    i bought this game from amazon because it was ...
# 1819    great styluses but they do not have the little...
# 1820    pros:sounds amazing.wireless.base is awesome a...
# 1821    this is a great trilogy of hard to find movies...
# 1822    in my opinion this is the best winnie the pooh...
# 1823    allen stone is the real deal. a true musician ...
# 1824    with the arrival of foggy and his office signs...
# 1825    no, it does not have that original, fresh char...
# 1826    i admired princess diana for the attention she...
# 1827    read and write speed are super quick with my c...
# 1828    a 6 months warranty does not instill confidenc...
# 1829    we have recently switched from independent sma...
# 1830    this viewsonic is 21.5 inches .  very light we...
# 1831    this case became an upgrade of my 9-year old a...
# 1832    this is an old family favorite.  it is great t...
# 1833    an all time favorite, i always remember when i...
# 1834    these speakers do an excellent job if you do n...
# 1835    it could be a 5 star product, but some lazy de...
# 1836    while i have had some hiccups with this keyboa...
# 1837    they are great for the whole family to reclaim...
# 1838    this is a terrific, excellent cd of queen's gr...
# Name: reviewText_clean, Length: 1839, dtype: object

# %%
# add number of characters column
reviews_train["nb_chars"] = reviews_train["reviewText"].apply(lambda x: len(x))

# add number of words column
reviews_train["nb_words"] = reviews_train["reviewText"].apply(lambda x: len(x.split(" ")))

# %%
# return the wordnet object value corresponding to the POS tag

import string
import nltk
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')

def get_wordnet_pos(pos_tag):
    if pos_tag.startswith('J'):
        return wordnet.ADJ
    elif pos_tag.startswith('V'):
        return wordnet.VERB
    elif pos_tag.startswith('N'):
        return wordnet.NOUN
    elif pos_tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN

def clean_text(text):
    # lower text
    text = text.lower()
    # tokenize text and remove puncutation
    text = [word.strip(string.punctuation) for word in text.split(" ")]
    # remove words that contain numbers
    text = [word for word in text if not any(c.isdigit() for c in word)]
    #stemming
    ps = PorterStemmer()
    text = [ps.stem(word) for word in text if not word in set(stopwords.words('english'))]
    # remove stop words
    stop = stopwords.words('english')
    text = [x for x in text if x not in stop]
    # remove empty tokens
    text = [t for t in text if len(t) > 0]
    # pos tag text
    pos_tags = pos_tag(text)
    # lemmatize text
    text = [WordNetLemmatizer().lemmatize(t[0], get_wordnet_pos(t[1])) for t in pos_tags]
    # remove words with only one letter
    text = [t for t in text if len(t) > 1]
    # join all
    text = " ".join(text)
    return(text)

# clean text data
reviews_train['reviewText_clean'] = reviews_train['reviewText_clean'].apply(lambda x: clean_text(x))
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\there\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\there\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\there\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# clean testing data
reviews_test['reviewText_clean'] = reviews_test['reviewText_clean'].apply(lambda x: clean_text(x))

# %%
reviews_train['reviewText_clean']
# Out:
# 0        come time super long cord room plug everyth or...
# 1        waterboy tough discern fan big music celtic fo...
# 2        use case month still absolut love still sign w...
# 3        old xbox gb hard drive get full need purchas a...
# 4        stori fast pace without obnoxi know get jason ...
# 5        movi arriv promis excel condition.....lov movi...
# 6        must clone laptop hard drive work straight box...
# 7        price perform realli know el say purchas two r...
# 8        summari like funni version star trek episod ti...
# 9        tell lot review titl effect clean come somewha...
# 10       think movi pretti good good actor good directo...
# 11       live mile due west chicago abl get normal netw...
# 12       fell hype.when deutsch grammophon announc rele...
# 13       buy set dvd heard cw go remak seri modern tele...
# 14       basic middl riddick saga anim chronicl survivo...
# 15       arriv time good dvd grandchild love danceto so...
# 16       alway love diana' music someth differ offer al...
# 17       nice fast card know card camera gopro black+' ...
# 18       seem lot nitpick review let cut chase import a...
# 19       purchas read review differ site return product...
# 20       first one would go sleep wake without power re...
# 21       clint usual best old gunsling william munni li...
# 22       pictur realli work conductor need find right b...
# 23       surpris see mani star review movi encourag hat...
# 24       state titl buy drive macbook pro far drive wor...
# 25       think one malle' best movi ever seen.i saw ope...
# 26       buy kindl year ago new paperwhit built-in ligh...
# 27       great devic order dad love job effici use powe...
# 28       sinc univers case lower expect think might cut...
# 29       short seem design build peopl know audio...not...
#                                ...
# 20553    take bit time heat ide march eventu turn taut ...
# 20554    consid mile davi first fusion electr period al...
# 20555    red fang tear tour support last album brillian...
# 20556    bluetooth mouse go solid perform issu sync thr...
# 20557    love wcar love love love uwwgtb one favorit al...
# 20558    good qualiti headphon system simpli connect ha...
# 20559    great song album includ poncho lefti need live...
# 20560    great len close focu unbeliev crop crystal cle...
# 20561    case fit nexu perfect cut-out right like way t...
# 20562    less expens option blackrapid doubl strap one ...
# 20563    bluray player directv dvr belkin wireless rout...
# 20564    bewar smart tv"today' dh daili email refer art...
# 20565    pretti pictur gobii dessert enough effect enou...
# 20566    barbara hershey never less watchabl intens cre...
# 20567    first issu unit three differ input jack period...
# 20568    get littl hesit i'd buy one store realli weak ...
# 20569    know i'm go told i'm wrong dvd celtic thunder'...
# 20570    life like mild spoiler life pretti dismal thre...
# 20571    easi set quiet transfer seem speedi even witho...
# 20572    part one film dvd nice romant tragedy..film fo...
# 20573    stumbl across movi tv one afternoon interact b...
# 20574    mid macbook pro charger save mani time paper p...
# 20575    daughter love movi whale dolphin realli enjoy ...
# 20576    start keyboard logitech find good build qualit...
# 20577    bought acer netbook intern dvd rom although ru...
# 20578    wonder dichotomi christma stori modern day tec...
# 20579    content certain episod triumph present particu...
# 20580    see movi year ago purchas cad next door neibor...
# 20581    love mel brook one plain suck though love movi...
# 20582    poor scrapper boston write script get hollywoo...
# Name: reviewText_clean, Length: 20583, dtype: object

# %%
reviews_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20583 entries, 0 to 20582
# Data columns (total 8 columns):
# overall             20583 non-null int64
# reviewText          20583 non-null object
# summary             20583 non-null object
# categoryName        20583 non-null object
# bucket              20583 non-null object
# reviewText_clean    20583 non-null object
# nb_chars            20583 non-null int64
# nb_words            20583 non-null int64
# dtypes: int64(3), object(5)
# memory usage: 1.3+ MB

# %% [markdown]
# ### Vectorizing text with gensim

# %%
import re  # For preprocessing
import pandas as pd  # For data handling
from time import time  # To time our operations
from collections import defaultdict  # For word frequency

import logging  # Setting up the loggings to monitor gensim
logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)

import gensim
from gensim.models.phrases import Phrases, Phraser
from gensim.models import word2vec
from gensim.test.utils import get_tmpfile, common_texts
from gensim.test.utils import common_texts
from gensim.models.doc2vec import Doc2Vec, TaggedDocument
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-ac606d4ec854> in <module>()
#       7 logging.basicConfig(format="%(levelname)s - %(asctime)s: %(message)s", datefmt= '%H:%M:%S', level=logging.INFO)
#       8
# ----> 9 import gensim
#      10 from gensim.models.phrases import Phrases, Phraser
#      11 from gensim.models import word2vec
#
# ModuleNotFoundError: No module named 'gensim'

# %%
# Therese code for gensim

# note: reviewText_clean is the cleaned text after applying the clean_text function

documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(reviews_train["reviewText_clean"].apply(lambda x: x.split(" ")))]

# train a Doc2Vec model with our text data
model = Doc2Vec(documents, vector_size=5, window=2, min_count=1, workers=4)

# transform each document into a vector data
doc2vec_df = reviews_train["reviewText_clean"].apply(lambda x: model.infer_vector(x.split(" "))).apply(pd.Series)
doc2vec_df.columns = ["doc2vec_vector_" + str(x) for x in doc2vec_df.columns]
reviews_train = pd.concat([reviews_train, doc2vec_df], axis=1)

# %%
# gensim for the test data

documents = [TaggedDocument(doc, [i]) for i, doc in enumerate(reviews_test["reviewText_clean"].apply(lambda x: x.split(" ")))]

# train a Doc2Vec model with our text data
model = Doc2Vec(documents, vector_size=5, window=2, min_count=1, workers=4)

# transform each document into a vector data
doc2vec_df_test = reviews_test["reviewText_clean"].apply(lambda x: model.infer_vector(x.split(" "))).apply(pd.Series)
doc2vec_df_test.columns = ["doc2vec_vector_" + str(x) for x in doc2vec_df_test.columns]
reviews_test = pd.concat([reviews_test, doc2vec_df_test], axis=1)

# %%
reviews_train

# %%
# add tf-idfs columns for training data
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(min_df = 10)
tfidf_result = tfidf.fit_transform(reviews_train["reviewText_clean"]).toarray()
tfidf_df = pd.DataFrame(tfidf_result, columns = tfidf.get_feature_names())
tfidf_df.columns = ["word_" + str(x) for x in tfidf_df.columns]
tfidf_df.index = reviews_train.index
reviews_df = pd.concat([reviews_train, tfidf_df], axis=1)

# %%
# add tf-idfs columns for testing data

tfidf = TfidfVectorizer(min_df = 10)
tfidf_result_test = tfidf.fit_transform(reviews_test["reviewText_clean"]).toarray()
tfidf_df_test = pd.DataFrame(tfidf_result_test, columns = tfidf.get_feature_names())
tfidf_df_test.columns = ["word_" + str(x) for x in tfidf_df_test.columns]
tfidf_df_test.index = reviews_test.index
reviews_df = pd.concat([reviews_test, tfidf_df_test], axis=1)

# %%
# add sentiment anaylsis columns
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sid = SentimentIntensityAnalyzer()
reviews_train["sentiments"] = reviews_train["reviewText_clean"].apply(lambda x: sid.polarity_scores(x))
reviews_train = pd.concat([reviews_train.drop(['sentiments'], axis=1), reviews_train['sentiments'].apply(pd.Series)], axis=1)

reviews_train

# %%
reviews_test["sentiments"] = reviews_test["reviewText_clean"].apply(lambda x: sid.polarity_scores(x))
reviews_test = pd.concat([reviews_test.drop(['sentiments'], axis=1), reviews_test['sentiments'].apply(pd.Series)], axis=1)

reviews_test

# %% [markdown]
# ### NLTK

# %%
all_reviews = reviews_train['reviewText_clean']
all_sent_values = []
all_sentiments = []

all_reviews_test = reviews_test['reviewText_clean']
all_sent_values_test = []
all_sentiments_test = []



from nltk.sentiment.vader import SentimentIntensityAnalyzer
def sentiment_value(paragraph):
    analyser = SentimentIntensityAnalyzer()
    result = analyser.polarity_scores(paragraph)
    score = result['compound']
    return round(score, 4)

import nltk
nltk.download('vader_lexicon')

# %% [markdown]
# ### Intervals
# [ -1, -0.5) : 1, Very Negative
#
# [-0.5, 0) : 2, Negative
#
# [0] : 3, Neutral
#
# (0, 0.5) : 4, Positive
#
# [0.5, 1] : 5, Very Positive

# %%
all_reviews

# %%
all_reviews_test

# %%
for i in range(0,20368):
    all_sent_values.append(sentiment_value(all_reviews[i])) 
    
for i in range(0,1839):
    all_sent_values_test.append(sentiment_value(all_reviews_test[i]))

# %%
len(all_sent_values)

len(all_sent_values_test)

# %%
# add raw score to dataframe
reviews_train['sentiment'] = all_sent_values

reviews_test['sentiment'] = all_sent_values_test

# %%
all_sent_values # ratings scaled from -1 to 1

# %%
# this changes the scale from -1 to 1 to a 1-5 scale. IGNORE FOR NOW

SENTIMENT_VALUE = []
SENTIMENT = []
for i in range(0,20368):
    sent = all_sent_values[i]
    if (sent<=1 and sent>=0.5):
        SENTIMENT.append('Very Positive')
        SENTIMENT_VALUE.append(5)
    elif (sent<0.5 and sent>0):
        SENTIMENT.append('Positive')
        SENTIMENT_VALUE.append(4)
    elif (sent==0):
        SENTIMENT.append('Neutral')
        SENTIMENT_VALUE.append(3)
    elif (sent<0 and sent>=-0.5):
        SENTIMENT.append('Negative')
        SENTIMENT_VALUE.append(2)
    else:
        SENTIMENT.append('Very Negative')
        SENTIMENT_VALUE.append(1)
        
reviews_train['SENTIMENT_VALUE'] = SENTIMENT_VALUE
reviews_train['SENTIMENT'] = SENTIMENT

# %%
reviews_train
#SENTIMENT_VALUE is the predicted rating --> disregard
#SENTIMENT is the verbal rating --> disregard

# %%
# NOTES

# for summary column, find frequency and use that to help predict the score

# calculate the frequency, then assign scores to groups of words --> then use this as a feature

# use product category as another feature

# *** use the outcome of the nlkt and utlize that as a feature along with the other given features in a logistic regression or other model

# basically use the nlkt as a model to generate a feature to be included in another model

# KNN can only be used as a continuous variable

# potential models: logistic model, decision tree, baseline logit model, Bayes classification, Bayes discriminant

# %% [markdown]
# ### Natural word processing of the summary column data

# %%
all_summary = reviews_train['summary']
all_sum_values = []
all_sum_sentiments = []

for i in range(0,20368):
    all_sum_values.append(sentiment_value(all_summary[i])) 
    
    
all_summary_test = reviews_test['summary']
all_sum_values_test = []
all_sum_sentiments_test = []

for i in range(0,1839):
    all_sum_values_test.append(sentiment_value(all_summary_test[i]))
    

# add raw score to dataframe
reviews_train['sentiment_summary'] = all_sum_values

reviews_test['sentiment_summary'] = all_sum_values_test

# %%
# Disregard scaling from 1-5 for now

SUMMARY_SENT_VALUE = []
SUMMARY_SENT = []
for i in range(0,20368):
    sent = all_sum_values[i]
    if (sent<=1 and sent>=0.5):
        SUMMARY_SENT.append('Very Positive')
        SUMMARY_SENT_VALUE.append(5)
    elif (sent<0.5 and sent>0):
        SUMMARY_SENT.append('Positive')
        SUMMARY_SENT_VALUE.append(4)
    elif (sent==0):
        SUMMARY_SENT.append('Neutral')
        SUMMARY_SENT_VALUE.append(3)
    elif (sent<0 and sent>=-0.5):
        SUMMARY_SENT.append('Negative')
        SUMMARY_SENT_VALUE.append(2)
    else:
        SUMMARY_SENT.append('Very Negative')
        SUMMARY_SENT_VALUE.append(1)
        
reviews_train['SUMMARY_SENT_VALUE'] = SUMMARY_SENT_VALUE
reviews_train['SUMMARY_SENT'] = SUMMARY_SENT

# %%
# Disregard for now

SUMMARY_SENT_VALUE_2 = []
SUMMARY_SENT_2 = []

for i in range(0,20368):
    sent = reviews_train['compound'][i]
    if (sent<=1 and sent>=0.5):
        SUMMARY_SENT_2.append('Very Positive')
        SUMMARY_SENT_VALUE_2.append(5)
    elif (sent<0.5 and sent>0):
        SUMMARY_SENT_2.append('Positive')
        SUMMARY_SENT_VALUE_2.append(4)
    elif (sent==0):
        SUMMARY_SENT_2.append('Neutral')
        SUMMARY_SENT_VALUE_2.append(3)
    elif (sent<0 and sent>=-0.5):
        SUMMARY_SENT_2.append('Negative')
        SUMMARY_SENT_VALUE_2.append(2)
    else:
        SUMMARY_SENT_2.append('Very Negative')
        SUMMARY_SENT_VALUE_2.append(1)
        
reviews_train['SUMMARY_SENT_VALUE'] = SUMMARY_SENT_VALUE_2
reviews_train['SUMMARY_SENT'] = SUMMARY_SENT_2

# %%
# one hot encoding of product categories for training data

Electronics = []

CDVinyl = []

MovieTV = []

CellPhone= []

VideoGames = []

for i in range(0,20368):
    categories = reviews_train['categoryName'][i]
    
    if (categories=='Electronics'):
        Electronics.append(1)
    else: 
        Electronics.append(0)
    
    if (categories == 'CDVinyl'):
        CDVinyl.append(1)
    else: 
        CDVinyl.append(0)
    
    if (categories == 'MovieTV'):
        MovieTV.append(1)
    else: 
        MovieTV.append(0)
    
    if (categories == 'CellPhone'):
        CellPhone.append(1)
    else: 
        CellPhone.append(0)
    
    if (categories == 'VideoGames'):
        VideoGames.append(1)
    else: 
        VideoGames.append(0)
        
reviews_train['Electronics'] = Electronics
reviews_train['CDVinyl'] = CDVinyl
reviews_train['MovieTV'] = MovieTV
reviews_train['CellPhone'] = CellPhone
reviews_train['VideoGames'] = VideoGames


reviews_train

# %%
# one hot encoding of product categories for testing data

Electronics_ = []

CDVinyl_ = []

MovieTV_ = []

CellPhone_ = []

VideoGames_ = []

for i in range(0,1839):
    categories_test = reviews_test['categoryName'][i]
    
    if (categories_test=='Electronics'):
        Electronics_.append(1)
    else: 
        Electronics_.append(0)
    
    if (categories_test == 'CDVinyl'):
        CDVinyl_.append(1)
    else: 
        CDVinyl_.append(0)
    
    if (categories_test == 'MovieTV'):
        MovieTV_.append(1)
    else: 
        MovieTV_.append(0)

    if (categories_test == 'CellPhone'):
        CellPhone_.append(1)
    else: 
        CellPhone_.append(0)
        
    if (categories_test == 'VideoGames'):
        VideoGames_.append(1)
    else:
        VideoGames_.append(0)
        
reviews_test['Electronics'] = Electronics_
reviews_test['CDVinyl'] = CDVinyl_
reviews_test['MovieTV'] = MovieTV_
reviews_test['CellPhone'] = CellPhone_
reviews_test['VideoGames'] = VideoGames_


reviews_test

# %%
reviews_train.info()

# %% [markdown]
# ## TRAINING AND FITTING MODELS

# %%
reviews_train

# variables: 'sentiment', 'sentiment_summary','neg', 'neu', 'pos', 'compound', 
# Electronics', 'CDVinyl', 'MovieTV', 'CellPhone', 'VideoGames', 

train_y = reviews_train['overall']

#train_x = reviews_train[['sentiment', 'sentiment_summary','neg', 'neu', 'pos']] # 0.52739 and 0.52719

#train_x = reviews_train[['sentiment', 'sentiment_summary','neg', 'neu', 'pos', 'compound']] # 0.52744 and 0.52719

train_x = reviews_train[['sentiment', 'sentiment_summary','neg', 'neu', 'pos', 'compound', 'Electronics', 'CDVinyl', 'MovieTV', 'CellPhone', 'VideoGames']] 
# 0.52867 and 0.52940

# train_x = reviews_train[['sentiment', 'sentiment_summary', 'compound', 'Electronics', 'CDVinyl', 'MovieTV', 'CellPhone', 'VideoGames']] # 0.52867 and 0.52940
# 0.52935 and 0.52911


from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(train_x, train_y,
                                                    test_size = 0.3, random_state = 0)

# I've split up the overall training data set into a training and testing portion
# so I am able to compare results and accuracy

# %%
#test_x = reviews_test[['sentiment', 'sentiment_summary','neg', 'neu', 'pos', 'compound', 'Electronics', 'CDVinyl', 'MovieTV', 'CellPhone', 'VideoGames']]

# %% [markdown]
# ### Logistic regression

# %%
# some packages and their uses

import pandas as pd 
import numpy as np
from sklearn import linear_model
from sklearn import metrics

# %%
# Train multi-classification model with logistic regression
lr = linear_model.LogisticRegression()
lr.fit(X_train, y_train)

y_pred_lr = lr.predict(X_test)

results_lr = pd.DataFrame({'Actual':y_test,'Predicted': y_pred_lr}) #prints out predicted ratings

results_lr

# %%
# Train multinomial logistic regression model
mul_lr = linear_model.LogisticRegression(multi_class='multinomial', solver='newton-cg').fit(X_train, y_train)

y_pred_mul_lr = mul_lr.predict(X_test)

results_mul_lr = pd.DataFrame({'Actual':y_test,'Predicted': y_pred_mul_lr}) #prints out predicted ratings

results_mul_lr

# %%
metrics.accuracy_score(y_test, lr.predict(X_test))

# %%
metrics.accuracy_score(y_test, mul_lr.predict(X_test))

# %% [markdown]
# ### Decision Tree

# %%
from sklearn import tree

clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)


metrics.accuracy_score(y_test, clf.predict(X_test))

y_pred_clf = clf.predict(X_test)

results_clf = pd.DataFrame({'Actual':y_test,'Predicted': y_pred_clf}) #prints out predicted ratings

results_clf

# %%
from sklearn import metrics  
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_clf))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_clf))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_clf)))

# %%
from sklearn.tree import DecisionTreeRegressor  

regressor = DecisionTreeRegressor()  
regressor.fit(X_train, y_train) 

y_pred = regressor.predict(X_test)

results_tree_regr = pd.DataFrame({'Actual':y_test,'Predicted': y_pred}) #prints out predicted ratings

results_tree_regr

# %%
from sklearn import metrics  
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))

# %% [markdown]
# ### Decision tree with Gini Index

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 

clf_gini = DecisionTreeClassifier(criterion = "gini", 
            random_state = 100,max_depth=3, min_samples_leaf=5) 

clf_gini.fit(X_train, y_train) 

y_pred_gini = regressor.predict(X_test)

results_gini = pd.DataFrame({'Actual':y_test,'Predicted': y_pred_gini}) #prints out predicted ratings

results_gini

# %%
from sklearn import metrics  
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_gini))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_gini))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_gini)))

# %% [markdown]
# ### Decision tree with enthropy

# %%
clf_entropy = DecisionTreeClassifier( 
            criterion = "entropy", random_state = 100, 
            max_depth = 3, min_samples_leaf = 5) 
  
     
clf_entropy.fit(X_train, y_train) 

y_pred_enthropy = regressor.predict(X_test)

results_enthropy = pd.DataFrame({'Actual':y_test,'Predicted': y_pred_enthropy}) #prints out predicted ratings

results_enthropy

# %%
from sklearn import metrics  
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred_enthropy))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred_enthropy))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred_enthropy)))

# %%
#Naive Bayes on different vectors
#Notes: pick which model you want to use since we did TF IDF, Ngram and other vectors

# Naive Bayes on Count Vectors
accuracy = train_model(naive_bayes.MultinomialNB(), X_train_count, y_train, X_test_count )
print "NB, Count Vectors: ", accuracy

# Naive Bayes on Word Level TF IDF Vectors already implemented
accuracy = train_model(naive_bayes.MultinomialNB(), X_train_tfidf, y_train, X_test_tfidf)
print "NB, WordLevel TF-IDF: ", accuracy

# Naive Bayes on Ngram Level TF IDF Vectors already implented
accuracy = train_model(naive_bayes.MultinomialNB(),  X_train_tfidf_ngram, y_train, X_test_tfidf_ngram)
print "NB, N-Gram Vectors: ", accuracy

# Naive Bayes on Character Level TF IDF Vectors
accuracy = train_model(naive_bayes.MultinomialNB(),  X_train_tfidf_ngram_chars, y_train, X_test_tfidf_ngram_chars')
print "NB, CharLevel Vectors: ", accuracy

# %%
#SVM  Model
#see variables

# SVM on Ngram Level TF IDF Vectors
accuracy = train_model(svm.SVC(),  xtrain_tfidf_ngram, y_train, X_test_tfidf_ngram)
print "SVM, N-Gram Vectors: ", accuracy

# %%
#Bagging Model
#see variables please

# RF on Count Vectors
accuracy = train_model(ensemble.RandomForestClassifier(),  X_train, y_train, X_test)
print "RF, Count Vectors: ", accuracy

# RF on Word Level TF IDF Vectors
accuracy = train_model(ensemble.RandomForestClassifier(),  X_train_tfidf, y_train, X_test_tfidf)
print "RF, WordLevel TF-IDF: ", accuracy

# %%
# Shallow Nueral Network
#see variables  please

def create_model_architecture(input_size):
    # create input layer 
    input_layer = layers.Input((input_size, ), sparse=True)
    
    # create hidden layer
    hidden_layer = layers.Dense(100, activation="relu")(input_layer)
    
    # create output layer
    output_layer = layers.Dense(1, activation="sigmoid")(hidden_layer)

    classifier = models.Model(inputs = input_layer, outputs = output_layer)
    classifier.compile(optimizer=optimizers.Adam(), loss='binary_crossentropy')
    return classifier 

classifier = create_model_architecture('xtrain_tfidf_ngram.shape[1]')
accuracy = train_model(classifier, X_train_tfidf_ngram, y_train, X_test_tfidf_ngram, is_neural_net=True)
print "NN, Ngram Level TF IDF Vectors",  accuracy
